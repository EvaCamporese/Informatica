# %% [markdown]
# # Esercizi

# %%
# Es 7.1: Scrivi la funzione cubo(n) che stampi a schermo un quadrato di lato nxn formato utilizzando il carattere *
#         Esempio:                       8 ->        * - - - - - - *     2 ->   * *
#                                                  / |           / |          * * *
#                                                /   |         /   |          * *
#                                              /     |       /     |
#                                            * - - - - - - *       |
#                                            |       |     |       |
#                                            |       |     |       |
#                                            |       * - - | - - - *
#                                            |     /       |     /
#                                            |   /         |   /
#                                            | /           | /
#                                            * - - - - - - *
#n=int(input())
#def cubo(n):
#    for i in range (0, n+(n/2)):
#        if i==o:
#            print (" " * (n/2) + "*" + "-" * (n-2) + "*")
#        elif i==4 or i==(n+(n/2))-1:
#            print ("*" + "-" * (n-2) + "*" + " " * (n/2))
#        elif:
#            print (" " * (n/2)-i + "/" + " " * i + "|" + " " * (n/2)+i + "/" + " " * i + "|")
#cubo(n)
#n=int(input())
#if n%2==0:
#    def cubo(n):
#        for i in range (0, n+(n/2)):
#            for j in range (0, n+(n/2)):
#                if i==0 or i==n/2 or i==(n+(n/2))-1:
#                    if j==0 or j==n/2 or j == n-1 or j==(n+(n/2))-1:
#                        print ("*")
#                    else:
#                        print ("-")
#                elif 
#n=int(input())
#if n%2==0:
#    def cubo(n):
#        for i in range (0, n+(n/2)):
#            for j in range (0, n+(n/2)):
#                if i==0:
#                    if j==(n/2) or j==(n+(n/2))-1:
#                        print("*")
#                    elif j>(n/2) and j<(n+(n/2))-1:
#                        print("-")
#                    else:
#                        print(" ")
#                elif i>0 and i<(n/2):
#                    print(" " * (n/2)-i + "/" + " " * i + "|" + " " * (n/2)+i + "/" + " " * i + "|")
#                elif i=(n/2):
#                    if j==0 or j==((n/2)-1):
#                        print ("*")
#                    elif j>0 and j<(n-1):
#                        print("-")
#                    else:
#                        print(" ")
#                elif i>(n/2) and i<(n-1):
#                    print("|" + " " * (n/2)-i + "|" + " " * n-(2((n/2)-i)) + " " * (n/2)-i + "|")
#                elif i==(n-1):
#                    print(" " * (n/2)-i + "*" + "-" * n-(2((n/2)-i)) + "-" * (n/2)-i + "*")
#                elif i>(n-1) and i<(n+(n/2))-1:
#                    print("|" + " " * (j) + "/" + " " * (i-j)+1 + "|" + " " * (j-i)-1 + "/" + " " * (i-j)+1)
#                elif i=(n+(n/2))-1:
#                    print("*" + "-" * (n-2) + "*" + " " * (n/2))
#else:
#    print("devi scegliere un numero pari!")
n=int(input())
if n%2==0:
    def cubo(n):
        for i in range (0, n+(n/2)):
            for j in range (0, n+(n/2)):
                if i==0:
                    if j==(n/2) or j==(n+(n/2))-1:
                        print("*")
                    elif j>(n/2) and j<(n+(n/2))-1:
                        print("-")
                    else:
                        print(" ")
                elif i>0 and i<(n/2):
                    print(" " * (n/2)-i + "/" + " " * i + "|" + " " * (n/2)+i + "/" + " " * i + "|")
                elif i=(n/2):
                    if j==0 or j==((n/2)-1):
                        print ("*")
                    elif j>0 and j<(n-1):
                        print("-")
                    else:
                        print(" ")
                elif i>(n/2) and i<(n-1):
                    print("|" + " " * (n/2)-i + "|" + " " * n-(2((n/2)-i)) + " " * (n/2)-i + "|")
                elif i==(n-1):
                    print(" " * (n/2)-i + "*" + "-" * n-(2((n/2)-i)) + "-" * (n/2)-i + "*")
                elif i>(n-1) and i<(n+(n/2))-1:
                    print("|" + " " * (j) + "/" + " " * (i-j)+1 + "|" + " " * (j-i)-1 + "/" + " " * (i-j)+1)
                elif i=(n+(n/2))-1:
                    print("*" + "-" * (n-2) + "*" + " " * (n/2))
else:
    print("devi scegliere un numero pari!")
